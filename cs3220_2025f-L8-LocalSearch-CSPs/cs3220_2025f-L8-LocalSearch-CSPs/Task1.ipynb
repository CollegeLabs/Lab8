# %%
Days = {1:"Monday", 2:"Tuesday", 3:"Wednesday", 4:"Thursday", 5:"Friday"}

print(Days.get(1))

Class = ["PPM - lec 1", "PPM - lec 2", "PPM - lab 1", "PPM - lab 2", "A - lec 1", "A - lec 2", "A - lab 1", "OS - lec 1", "OS - lec 2", "OS - lab 1", "DB - lec 1", "DB - lec 2", "DB - lab 1"]
# Out:
# Monday

# %%
constraints={}
